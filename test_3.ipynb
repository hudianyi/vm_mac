# %%
import numpy as np
import pandas as pd

train_x = np.load('data/trainx_runath1_50.npy')
train_y = np.load('data/trainy_runath1_50.npy')
test_x = np.load('data/testx_runath1_50.npy')
test_y = np.load('data/testy_runath1_50.npy')

# %%
print(train_x.shape)
print(train_y.shape)
print(test_x.shape)
print(test_y.shape)
# Out:
# (798, 50, 17)
# (798,)
# (165, 50, 17)
# (165,)

# %%
test_y.reshape(-1,1)
# Out:
# array([[56.1786 ],
#        [57.2523 ],
#        [56.64495],
#        [54.5025 ],
#        [61.41315],
#        [63.26625],
#        [60.44715],
#        [67.7304 ],
#        [59.4636 ],
#        [66.8805 ],
#        [70.34235],
#        [69.8505 ],
#        [65.28465],
#        [65.6865 ],
#        [61.5069 ],
#        [61.56705],
#        [65.17935],
#        [63.44025],
#        [64.84635],
#        [63.4305 ],
#        [58.3209 ],
#        [73.0947 ],
#        [72.55245],
#        [72.3144 ],
#        [69.84885],
#        [82.56705],
#        [78.6405 ],
#        [79.3182 ],
#        [76.62405],
#        [78.12675],
#        [81.9171 ],
#        [77.5011 ],
#        [74.08875],
#        [77.4192 ],
#        [72.86985],
#        [72.13485],
#        [71.8215 ],
#        [76.2573 ],
#        [70.56045],
#        [69.4038 ],
#        [70.5174 ],
#        [70.51065],
#        [70.04175],
#        [72.10245],
#        [70.5963 ],
#        [74.05815],
#        [72.5712 ],
# ...
